# %%
# Import libraires
import gymnasium as gym
from huggingface_sb3 import  package_to_hub
from huggingface_hub import (
    notebook_login,
)

from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Create environment
env = gym.make('LunarLander-v2')

# Create the DQN model
model = DQN(
    policy="MlpPolicy",
    env=env,
    learning_rate=1e-4,
    buffer_size=100000,
    learning_starts=1000,
    batch_size=64,
    tau=1.0,
    gamma=0.99,
    train_freq=4,
    gradient_steps=1,
    target_update_interval=1000,
    exploration_fraction=0.1,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.05,
    max_grad_norm=10,
    tensorboard_log="./dqn_lunarlander_tensorboard/",
    policy_kwargs=dict(net_arch=[256, 256]),
    verbose=1
)


# Train the model
model.learn(total_timesteps=1000000, log_interval=10)

# Save trained model
model_name = "dqn-LunarLander-v2"
model.save(model_name)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./dqn_lunarlander_tensorboard/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -251     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 14267    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 922      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.8     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1490     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1715     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.3     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 1093     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2588     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 396      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 966      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3474     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.5      |
# |    n_updates        | 618      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 833      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4436     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93     |
# |    n_updates        | 858      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 723      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5465     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.06     |
# |    n_updates        | 1116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 660      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 6381     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.699    |
# |    n_updates        | 1345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 613      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7394     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69     |
# |    n_updates        | 1598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 90       |
# |    fps              | 581      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8468     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 1866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 556      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 9574     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.308    |
# |    n_updates        | 2143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 110      |
# |    fps              | 541      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 10504    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.372    |
# |    n_updates        | 2375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 527      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 11584    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.957    |
# |    n_updates        | 2645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 130      |
# |    fps              | 517      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 12510    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 2877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 509      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 13457    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.386    |
# |    n_updates        | 3114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 150      |
# |    fps              | 501      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.538    |
# |    n_updates        | 3349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 495      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 15417    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 3604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 170      |
# |    fps              | 490      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 16439    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.933    |
# |    n_updates        | 3859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 485      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 17477    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.344    |
# |    n_updates        | 4119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 190      |
# |    fps              | 481      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 18533    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.8      |
# |    n_updates        | 4383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 476      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 19558    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.666    |
# |    n_updates        | 4639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 210      |
# |    fps              | 472      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 20664    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.41     |
# |    n_updates        | 4915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 469      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 21633    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.61     |
# |    n_updates        | 5158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 230      |
# |    fps              | 465      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 22608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 5401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 462      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 23530    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.723    |
# |    n_updates        | 5632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 250      |
# |    fps              | 458      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 24543    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.94     |
# |    n_updates        | 5885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -98.2    |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 456      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 25576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.533    |
# |    n_updates        | 6143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -94.6    |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 270      |
# |    fps              | 454      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 26623    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.06     |
# |    n_updates        | 6405     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -92      |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 451      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 27954    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 6738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -86.2    |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 290      |
# |    fps              | 450      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 29067    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 7016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -83.9    |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 448      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 30039    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 7259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -83      |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 310      |
# |    fps              | 446      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 31162    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.425    |
# |    n_updates        | 7540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -82.7    |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 445      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 32316    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.57     |
# |    n_updates        | 7828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -78.7    |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 330      |
# |    fps              | 443      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 33700    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 8174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -77      |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 441      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 34867    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.521    |
# |    n_updates        | 8466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -77.5    |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 350      |
# |    fps              | 439      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 35948    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.92     |
# |    n_updates        | 8736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -75.3    |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 438      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 37073    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.42     |
# |    n_updates        | 9018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -71.3    |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 370      |
# |    fps              | 437      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 38340    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.934    |
# |    n_updates        | 9334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -70.5    |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 435      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 39756    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 9688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -69.2    |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 390      |
# |    fps              | 434      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 41036    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.949    |
# |    n_updates        | 10008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -66.7    |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 433      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 42167    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.861    |
# |    n_updates        | 10291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -64.3    |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 410      |
# |    fps              | 431      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 43735    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.702    |
# |    n_updates        | 10683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -60.9    |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 430      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 45743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 11185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | -58      |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 430      |
# |    fps              | 429      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 46817    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 11454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -53.7    |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 428      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 48184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.814    |
# |    n_updates        | 11795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | -53.7    |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 450      |
# |    fps              | 427      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 49852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03     |
# |    n_updates        | 12212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | -51.1    |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 425      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 52036    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 12758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -51.5    |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 470      |
# |    fps              | 424      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 54285    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 13321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -51.8    |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 423      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 56452    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 13862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -50.4    |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 490      |
# |    fps              | 421      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 58361    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 14340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -54.7    |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 420      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 62159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 15289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | -55      |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 510      |
# |    fps              | 417      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 67923    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.737    |
# |    n_updates        | 16730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 289      |
# |    ep_rew_mean      | -55.9    |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 414      |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 74649    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 18412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | -54.7    |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 530      |
# |    fps              | 410      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 84649    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.808    |
# |    n_updates        | 20912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | -55      |
# |    exploration_rate | 0.101    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 406      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 94649    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.821    |
# |    n_updates        | 23412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 548      |
# |    ep_rew_mean      | -49.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 550      |
# |    fps              | 403      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 104649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.855    |
# |    n_updates        | 25912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 626      |
# |    ep_rew_mean      | -48.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 400      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 114649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.773    |
# |    n_updates        | 28412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | -45.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 570      |
# |    fps              | 397      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 124649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 30912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 782      |
# |    ep_rew_mean      | -41.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 395      |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 134649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45     |
# |    n_updates        | 33412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 863      |
# |    ep_rew_mean      | -39      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 590      |
# |    fps              | 394      |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 144649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.95     |
# |    n_updates        | 35912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 918      |
# |    ep_rew_mean      | -35.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 392      |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 153918   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.324    |
# |    n_updates        | 38229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 954      |
# |    ep_rew_mean      | -37.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 610      |
# |    fps              | 391      |
# |    time_elapsed     | 417      |
# |    total_timesteps  | 163373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.28     |
# |    n_updates        | 40593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 986      |
# |    ep_rew_mean      | -36.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 391      |
# |    time_elapsed     | 442      |
# |    total_timesteps  | 173210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.225    |
# |    n_updates        | 43052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 982      |
# |    ep_rew_mean      | -37.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 630      |
# |    fps              | 392      |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 182833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.19     |
# |    n_updates        | 45458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 982      |
# |    ep_rew_mean      | -35.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 389      |
# |    time_elapsed     | 495      |
# |    total_timesteps  | 192833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.159    |
# |    n_updates        | 47958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 982      |
# |    ep_rew_mean      | -34.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 650      |
# |    fps              | 386      |
# |    time_elapsed     | 524      |
# |    total_timesteps  | 202833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 50458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 976      |
# |    ep_rew_mean      | -31.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 384      |
# |    time_elapsed     | 551      |
# |    total_timesteps  | 212216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 52803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 976      |
# |    ep_rew_mean      | -29.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 670      |
# |    fps              | 383      |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 222216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 55303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 976      |
# |    ep_rew_mean      | -26.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 381      |
# |    time_elapsed     | 608      |
# |    total_timesteps  | 232216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 57803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 976      |
# |    ep_rew_mean      | -24.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 690      |
# |    fps              | 380      |
# |    time_elapsed     | 637      |
# |    total_timesteps  | 242216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.266    |
# |    n_updates        | 60303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 378      |
# |    time_elapsed     | 666      |
# |    total_timesteps  | 252216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 62803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | -11.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 710      |
# |    fps              | 376      |
# |    time_elapsed     | 696      |
# |    total_timesteps  | 262216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.156    |
# |    n_updates        | 65303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 990      |
# |    ep_rew_mean      | -9.04    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 374      |
# |    time_elapsed     | 725      |
# |    total_timesteps  | 272216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.166    |
# |    n_updates        | 67803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | -6.62    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 730      |
# |    fps              | 373      |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 282216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 70303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | -7.37    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 371      |
# |    time_elapsed     | 786      |
# |    total_timesteps  | 292216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 72803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | -7       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 750      |
# |    fps              | 370      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 302216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 75303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -8.25    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 368      |
# |    time_elapsed     | 846      |
# |    total_timesteps  | 312216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 77803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -9.72    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 770      |
# |    fps              | 367      |
# |    time_elapsed     | 876      |
# |    total_timesteps  | 322216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 80303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -12.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 366      |
# |    time_elapsed     | 906      |
# |    total_timesteps  | 332216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.216    |
# |    n_updates        | 82803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -16.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 790      |
# |    fps              | 366      |
# |    time_elapsed     | 934      |
# |    total_timesteps  | 342216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 85303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -15.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 365      |
# |    time_elapsed     | 963      |
# |    total_timesteps  | 352216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.192    |
# |    n_updates        | 87803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -16.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 810      |
# |    fps              | 364      |
# |    time_elapsed     | 993      |
# |    total_timesteps  | 362216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 90303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -18      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 367      |
# |    time_elapsed     | 1014     |
# |    total_timesteps  | 372216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 92803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -19.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 830      |
# |    fps              | 367      |
# |    time_elapsed     | 1038     |
# |    total_timesteps  | 382216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.24     |
# |    n_updates        | 95303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | -26.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 369      |
# |    time_elapsed     | 1060     |
# |    total_timesteps  | 391718   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 97679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | -24.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 850      |
# |    fps              | 370      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 401718   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 100179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | -21.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 372      |
# |    time_elapsed     | 1105     |
# |    total_timesteps  | 411355   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 102588   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 870      |
# |    fps              | 373      |
# |    time_elapsed     | 1129     |
# |    total_timesteps  | 421355   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 105088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 973      |
# |    ep_rew_mean      | -8.95    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 373      |
# |    time_elapsed     | 1149     |
# |    total_timesteps  | 429561   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 107140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 962      |
# |    ep_rew_mean      | -7.96    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 890      |
# |    fps              | 374      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 438420   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 109354   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 951      |
# |    ep_rew_mean      | -4.91    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 376      |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 447276   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.278    |
# |    n_updates        | 111568   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 923      |
# |    ep_rew_mean      | 9.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 910      |
# |    fps              | 377      |
# |    time_elapsed     | 1205     |
# |    total_timesteps  | 454560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.196    |
# |    n_updates        | 113389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 893      |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    time_elapsed     | 2383     |
# |    total_timesteps  | 891955   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 222738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | 251      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1890     |
# |    fps              | 373      |
# |    time_elapsed     | 2395     |
# |    total_timesteps  | 895763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 223690   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 359      |
# |    ep_rew_mean      | 250      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 373      |
# |    time_elapsed     | 2408     |
# |    total_timesteps  | 900079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4      |
# |    n_updates        | 224769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 365      |
# |    ep_rew_mean      | 251      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1910     |
# |    fps              | 373      |
# |    time_elapsed     | 2420     |
# |    total_timesteps  | 903920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.688    |
# |    n_updates        | 225729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 380      |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1920     |
# |    fps              | 373      |
# |    time_elapsed     | 2435     |
# |    total_timesteps  | 908647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0833   |
# |    n_updates        | 226911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 386      |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1930     |
# |    fps              | 372      |
# |    time_elapsed     | 2449     |
# |    total_timesteps  | 912919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0686   |
# |    n_updates        | 227979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 390      |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1940     |
# |    fps              | 372      |
# |    time_elapsed     | 2462     |
# |    total_timesteps  | 917165   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.585    |
# |    n_updates        | 229041   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 401      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1950     |
# |    fps              | 372      |
# |    time_elapsed     | 2477     |
# |    total_timesteps  | 921507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0536   |
# |    n_updates        | 230126   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 401      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1960     |
# |    fps              | 371      |
# |    time_elapsed     | 2488     |
# |    total_timesteps  | 925044   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.492    |
# |    n_updates        | 231010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1970     |
# |    fps              | 371      |
# |    time_elapsed     | 2500     |
# |    total_timesteps  | 928857   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0613   |
# |    n_updates        | 231964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1980     |
# |    fps              | 371      |
# |    time_elapsed     | 2516     |
# |    total_timesteps  | 933775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0886   |
# |    n_updates        | 233193   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 417      |
# |    ep_rew_mean      | 240      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1990     |
# |    fps              | 370      |
# |    time_elapsed     | 2527     |
# |    total_timesteps  | 937427   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0494   |
# |    n_updates        | 234106   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 370      |
# |    time_elapsed     | 2538     |
# |    total_timesteps  | 941293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0742   |
# |    n_updates        | 235073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 405      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2010     |
# |    fps              | 370      |
# |    time_elapsed     | 2547     |
# |    total_timesteps  | 944386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 235846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 389      |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2020     |
# |    fps              | 370      |
# |    time_elapsed     | 2556     |
# |    total_timesteps  | 947555   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.342    |
# |    n_updates        | 236638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 383      |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2030     |
# |    fps              | 370      |
# |    time_elapsed     | 2567     |
# |    total_timesteps  | 951252   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 237562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 375      |
# |    ep_rew_mean      | 250      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 370      |
# |    time_elapsed     | 2576     |
# |    total_timesteps  | 954645   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.5      |
# |    n_updates        | 238411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 365      |
# |    ep_rew_mean      | 253      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2050     |
# |    fps              | 370      |
# |    time_elapsed     | 2586     |
# |    total_timesteps  | 958014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 239253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 361      |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 370      |
# |    time_elapsed     | 2595     |
# |    total_timesteps  | 961117   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0958   |
# |    n_updates        | 240029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 352      |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2070     |
# |    fps              | 370      |
# |    time_elapsed     | 2604     |
# |    total_timesteps  | 964087   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0896   |
# |    n_updates        | 240771   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 331      |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 370      |
# |    time_elapsed     | 2612     |
# |    total_timesteps  | 966866   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0562   |
# |    n_updates        | 241466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2090     |
# |    fps              | 369      |
# |    time_elapsed     | 2621     |
# |    total_timesteps  | 969939   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.279    |
# |    n_updates        | 242234   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 322      |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 369      |
# |    time_elapsed     | 2632     |
# |    total_timesteps  | 973488   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 243121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 324      |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2110     |
# |    fps              | 369      |
# |    time_elapsed     | 2641     |
# |    total_timesteps  | 976757   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.31     |
# |    n_updates        | 243939   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | 258      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 369      |
# |    time_elapsed     | 2651     |
# |    total_timesteps  | 980018   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.7      |
# |    n_updates        | 244754   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 317      |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2130     |
# |    fps              | 369      |
# |    time_elapsed     | 2659     |
# |    total_timesteps  | 982999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 245499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 324      |
# |    ep_rew_mean      | 258      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 369      |
# |    time_elapsed     | 2671     |
# |    total_timesteps  | 987070   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 246517   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2150     |
# |    fps              | 369      |
# |    time_elapsed     | 2682     |
# |    total_timesteps  | 990504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0629   |
# |    n_updates        | 247375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 326      |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 369      |
# |    time_elapsed     | 2691     |
# |    total_timesteps  | 993680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 248169   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 323      |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2170     |
# |    fps              | 369      |
# |    time_elapsed     | 2699     |
# |    total_timesteps  | 996420   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0853   |
# |    n_updates        | 248854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 328      |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 369      |
# |    time_elapsed     | 2709     |
# |    total_timesteps  | 999673   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.757    |
# |    n_updates        | 249668   |
# ----------------------------------

# %%
# Save trained model
model_name = "dqn-LunarLander-v2"
model.save(model_name)

# %%
# Evaluate and see results
eval_env = Monitor(gym.make('LunarLander-v2', render_mode="human"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=2, deterministic=True)
print(f"mean_reward={mean_reward:.2f}+/-{std_reward}")
eval_env.close()
# Out:
# mean_reward=277.54+/-2.342390999999992

# %%
package_to_hub(model = model,
               model_name="Belwen/dqn-LunarLander-v2",
               model_architecture="DQN",
               env_id="LunarLander-v2",
               eval_env=DummyVecEnv([lambda: Monitor(gym.make("LunarLander-v2", render_mode="rgb_array"))]),
               repo_id="Belwen/dqn-LunarLander-v2",
               commit_message="Upload trained dqn LunarLander")
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'C:\Users\Sarah\AppData\Local\Temp\tmp76lsepee\Belwen' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# Saving video to C:\Users\Sarah\AppData\Local\Temp\tmphw8gx418\-step-0-to-step-1000.mp4
# Moviepy - Building video C:\Users\Sarah\AppData\Local\Temp\tmphw8gx418\-step-0-to-step-1000.mp4.
# Moviepy - Writing video C:\Users\Sarah\AppData\Local\Temp\tmphw8gx418\-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready C:\Users\Sarah\AppData\Local\Temp\tmphw8gx418\-step-0-to-step-1000.mp4
# ℹ Pushing repo Belwen/dqn-LunarLander-v2 to the Hugging Face Hub
# policy.optimizer.pth:   0%|          | 0.00/558k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# policy.pth:   0%|          | 0.00/557k [00:00<?, ?B/s]
# dqn-LunarLander-v2.zip:   0%|          | 0.00/1.13M [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Belwen/dqn-LunarLander-v2/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Belwen/dqn-LunarLander-v2/commit/7c94efb3e0d91c1d1902957efbc96ef712b7e759', commit_message='Upload trained dqn LunarLander', commit_description='', oid='7c94efb3e0d91c1d1902957efbc96ef712b7e759', pr_url=None, pr_revision=None, pr_num=None)
