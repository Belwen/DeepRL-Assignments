# %%
# Import libraires
import gymnasium as gym
from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Create environment
env = gym.make('LunarLander-v2', render_mode="rgb_array")

# Create agent
model = PPO(policy='MlpPolicy', 
            env=env, 
            n_steps=1024,
            n_epochs=4,
            gamma=.999,
            gae_lambda=0.98,
            batch_size=64,
            ent_coef=0.01,
            verbose=1
        )

# train agent
model.learn(total_timesteps=1000000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.4     |
# |    ep_rew_mean     | -241     |
# | time/              |          |
# |    fps             | 2414     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95            |
# |    ep_rew_mean          | -241          |
# | time/                   |               |
# |    fps                  | 1648          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 0.00097438146 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.00369       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.8e+03       |
# |    n_updates            | 4             |
# |    policy_gradient_loss | -0.00272      |
# |    value_loss           | 9.42e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93            |
# |    ep_rew_mean          | -208          |
# | time/                   |               |
# |    fps                  | 1503          |
# |    iterations           | 3             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00084627804 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00215       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.05e+03      |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.00333      |
# |    value_loss           | 1.01e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.3          |
# |    ep_rew_mean          | -220          |
# | time/                   |               |
# |    fps                  | 1444          |
# |    iterations           | 4             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00022170244 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00874      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.76e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.00107      |
# |    value_loss           | 6.23e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 91.9          |
# |    ep_rew_mean          | -208          |
# | time/                   |               |
# |    fps                  | 1409          |
# |    iterations           | 5             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00060758897 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0164       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.58e+03      |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.00259      |
# |    value_loss           | 1.01e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.5          |
# |    ep_rew_mean          | -196          |
# | time/                   |               |
# |    fps                  | 1382          |
# |    iterations           | 6             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00034158689 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0159       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.73e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00127      |
# |    value_loss           | 3.7e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93           |
# |    ep_rew_mean          | -187         |
# | time/                   |              |
# |    fps                  | 1372         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0012545701 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5e+03      |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 3e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.3         |
# |    ep_rew_mean          | -180         |
# | time/                   |              |
# |    fps                  | 1358         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0009015822 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00616     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 920          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 1.91e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.4          |
# |    ep_rew_mean          | -176          |
# | time/                   |               |
# |    fps                  | 1346          |
# |    iterations           | 9             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00044707232 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00714      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.31e+03      |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.00162      |
# |    value_loss           | 3.11e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.2         |
# |    ep_rew_mean          | -161         |
# | time/                   |              |
# |    fps                  | 1339         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0016613421 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.012       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 3.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92           |
# |    ep_rew_mean          | -152         |
# | time/                   |              |
# |    fps                  | 1338         |
# |    iterations           | 11           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0031120223 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00274     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 762          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00587     |
# |    value_loss           | 1.46e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 92.9          |
# |    ep_rew_mean          | -148          |
# | time/                   |               |
# |    fps                  | 1331          |
# |    iterations           | 12            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00042973872 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00325      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.94e+03      |
# |    n_updates            | 44            |
# |    policy_gradient_loss | -0.00115      |
# |    value_loss           | 3.32e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.9        |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 1329        |
# |    iterations           | 13          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.002657043 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00685    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+03    |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 1.97e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.2         |
# |    ep_rew_mean          | -136         |
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 14           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0023448977 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0032      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+03     |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 5.26e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.1         |
# |    ep_rew_mean          | -136         |
# | time/                   |              |
# |    fps                  | 1317         |
# |    iterations           | 15           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0018939783 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000351    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+03     |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 2.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.1         |
# |    ep_rew_mean          | -134         |
# | time/                   |              |
# |    fps                  | 1312         |
# |    iterations           | 16           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0021209377 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000274    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 4.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.6         |
# |    ep_rew_mean          | -133         |
# | time/                   |              |
# |    fps                  | 1308         |
# |    iterations           | 17           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0049669696 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0112      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 482          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 1.22e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 99.9          |
# |    ep_rew_mean          | -129          |
# | time/                   |               |
# |    fps                  | 1309          |
# |    iterations           | 18            |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00095787056 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0012       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.07e+03      |
# |    n_updates            | 68            |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 2.28e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 1301         |
# |    iterations           | 19           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0063020615 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00486     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 592          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00685     |
# |    value_loss           | 1.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 20          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008996406 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00534    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 576         |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 1.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 1297        |
# |    iterations           | 21          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.010325156 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.000612   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 462         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 1.07e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 1296         |
# |    iterations           | 22           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0053055766 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.00284     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 727          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.0055      |
# |    value_loss           | 1.7e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 23          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.007160045 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.000132   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 924         |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 1288         |
# |    iterations           | 24           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0071896985 |
# |    clip_fraction        | 0.0876       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.0039      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 491          |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00933     |
# |    value_loss           | 868          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 25          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.013333588 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -0.00109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 188         |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.0099     |
# |    value_loss           | 569         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | -104         |
# | time/                   |              |
# |    fps                  | 1285         |
# |    iterations           | 26           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0008076967 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.00768     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 349          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 947          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | -102         |
# | time/                   |              |
# |    fps                  | 1282         |
# |    iterations           | 27           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0035701469 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.00104     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 370          |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 684          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | -92.9        |
# | time/                   |              |
# |    fps                  | 1279         |
# |    iterations           | 28           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0018993723 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.00025     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 209          |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 469          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | -94.6       |
# | time/                   |             |
# |    fps                  | 1277        |
# |    iterations           | 29          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.010186177 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.00018    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 235         |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 586         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 138           |
# |    ep_rew_mean          | -94.6         |
# | time/                   |               |
# |    fps                  | 1276          |
# |    iterations           | 30            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.9542349e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.16         |
# |    explained_variance   | -0.00974      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 521           |
# |    n_updates            | 116           |
# |    policy_gradient_loss | 0.000247      |
# |    value_loss           | 1.26e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 143          |
# |    ep_rew_mean          | -91.3        |
# | time/                   |              |
# |    fps                  | 1275         |
# |    iterations           | 31           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0012480111 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.000288    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 621          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -89.8       |
# | time/                   |             |
# |    fps                  | 1272        |
# |    iterations           | 32          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017517434 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.000108   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 345         |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 646         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 147           |
# |    ep_rew_mean          | -86.4         |
# | time/                   |               |
# |    fps                  | 1270          |
# |    iterations           | 33            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.00081844954 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | -0.000552     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 359           |
# |    n_updates            | 128           |
# |    policy_gradient_loss | 0.000647      |
# |    value_loss           | 1.07e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | -81.5       |
# | time/                   |             |
# |    fps                  | 1269        |
# |    iterations           | 34          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009012231 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.000145   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 132         |
# |    policy_gradient_loss | 0.000358    |
# |    value_loss           | 439         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | -79.5       |
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 35          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009402555 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -7.47e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 338         |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 742         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 148           |
# |    ep_rew_mean          | -71.7         |
# | time/                   |               |
# |    fps                  | 1263          |
# |    iterations           | 36            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00012683356 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.24         |
# |    explained_variance   | -4.96e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 309           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00092      |
# |    value_loss           | 656           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | -70.1        |
# | time/                   |              |
# |    fps                  | 1258         |
# |    iterations           | 37           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0018391202 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -7.71e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 90.1         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 296          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | -70.6       |
# | time/                   |             |
# |    fps                  | 1253        |
# |    iterations           | 38          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.001664602 |
# |    clip_fraction        | 0.00488     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.02        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 146         |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00376    |
# |    value_loss           | 234         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 155           |
# |    ep_rew_mean          | -70.9         |
# | time/                   |               |
# |    fps                  | 1247          |
# |    iterations           | 39            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 39936         |
# | train/                  |               |
# |    approx_kl            | 0.00021359825 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | 0.0599        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 159           |
# |    n_updates            | 152           |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 355           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | -68.8       |
# | time/                   |             |
# |    fps                  | 1243        |
# |    iterations           | 40          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009163986 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.000543   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 278         |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 528         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -66.4       |
# | time/                   |             |
# |    fps                  | 1238        |
# |    iterations           | 41          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.009271708 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.000413   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 390         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -64.3       |
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 42          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.002883554 |
# |    clip_fraction        | 0.000977    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.000284   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 188         |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.000711   |
# |    value_loss           | 344         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 152        |
# |    ep_rew_mean          | -66.6      |
# | time/                   |            |
# |    fps                  | 1232       |
# |    iterations           | 43         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 44032      |
# | train/                  |            |
# |    approx_kl            | 0.01576523 |
# |    clip_fraction        | 0.0835     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | -0.000318  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 204        |
# |    n_updates            | 168        |
# |    policy_gradient_loss | -0.00733   |
# |    value_loss           | 464        |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 150           |
# |    ep_rew_mean          | -63.9         |
# | time/                   |               |
# |    fps                  | 1229          |
# |    iterations           | 44            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00013105507 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.11         |
# |    explained_variance   | -0.000731     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 542           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | -0.00069      |
# |    value_loss           | 1e+03         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | -64.8        |
# | time/                   |              |
# |    fps                  | 1225         |
# |    iterations           | 45           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0015606119 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | -0.00693     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 584          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 150           |
# |    ep_rew_mean          | -63.2         |
# | time/                   |               |
# |    fps                  | 1223          |
# |    iterations           | 46            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00013237505 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | -0.00487      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 819           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000198     |
# |    value_loss           | 1.75e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | -61.7       |
# | time/                   |             |
# |    fps                  | 1220        |
# |    iterations           | 47          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.004386709 |
# |    clip_fraction        | 0.00708     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -7.63e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 254         |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 547         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | -64.4        |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 48           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0059426464 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.000151    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 217          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 524          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | -64          |
# | time/                   |              |
# |    fps                  | 1213         |
# |    iterations           | 49           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0023092367 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -0.00123     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 567          |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | -62.6        |
# | time/                   |              |
# |    fps                  | 1211         |
# |    iterations           | 50           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0022380096 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.000647     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 349          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 685          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 171           |
# |    ep_rew_mean          | -64.8         |
# | time/                   |               |
# |    fps                  | 1208          |
# |    iterations           | 51            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 52224         |
# | train/                  |               |
# |    approx_kl            | 0.00055671827 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 0.0185        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 82            |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000889     |
# |    value_loss           | 152           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | -64.9       |
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 52          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.000162701 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.00688    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 299         |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.000558   |
# |    value_loss           | 877         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | -63          |
# | time/                   |              |
# |    fps                  | 1204         |
# |    iterations           | 53           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0012356313 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.00914      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 275          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 534          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 183          |
# |    ep_rew_mean          | -62.7        |
# | time/                   |              |
# |    fps                  | 1201         |
# |    iterations           | 54           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0019267724 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0633       |
# ...
# |    fps                  | 922          |
# |    iterations           | 960          |
# |    time_elapsed         | 1065         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0004708718 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 504          |
# |    n_updates            | 3836         |
# |    policy_gradient_loss | -0.000707    |
# |    value_loss           | 857          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 374           |
# |    ep_rew_mean          | 243           |
# | time/                   |               |
# |    fps                  | 922           |
# |    iterations           | 961           |
# |    time_elapsed         | 1066          |
# |    total_timesteps      | 984064        |
# | train/                  |               |
# |    approx_kl            | 0.00025828445 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.645        |
# |    explained_variance   | 0.59          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 210           |
# |    n_updates            | 3840          |
# |    policy_gradient_loss | -0.000268     |
# |    value_loss           | 804           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 373          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 962          |
# |    time_elapsed         | 1068         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0022023623 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.603       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.98         |
# |    n_updates            | 3844         |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 35.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 963          |
# |    time_elapsed         | 1069         |
# |    total_timesteps      | 986112       |
# | train/                  |              |
# |    approx_kl            | 0.0013866359 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5          |
# |    n_updates            | 3848         |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 19           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 964          |
# |    time_elapsed         | 1070         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0051989425 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.48         |
# |    n_updates            | 3852         |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 11           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 372         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 965         |
# |    time_elapsed         | 1071        |
# |    total_timesteps      | 988160      |
# | train/                  |             |
# |    approx_kl            | 0.007221556 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6           |
# |    n_updates            | 3856        |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 18.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 966          |
# |    time_elapsed         | 1072         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0060836812 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34         |
# |    n_updates            | 3860         |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 9.67         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 967          |
# |    time_elapsed         | 1074         |
# |    total_timesteps      | 990208       |
# | train/                  |              |
# |    approx_kl            | 0.0068428777 |
# |    clip_fraction        | 0.095        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.643       |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 667          |
# |    n_updates            | 3864         |
# |    policy_gradient_loss | -0.00025     |
# |    value_loss           | 949          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 968         |
# |    time_elapsed         | 1075        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.003543703 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.14        |
# |    n_updates            | 3868        |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 969         |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 992256      |
# | train/                  |             |
# |    approx_kl            | 0.003114428 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03        |
# |    n_updates            | 3872        |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 11.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 377          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 970          |
# |    time_elapsed         | 1077         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0036007506 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 3876         |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 31.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 971          |
# |    time_elapsed         | 1079         |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0034724963 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.73         |
# |    n_updates            | 3880         |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 8.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 972          |
# |    time_elapsed         | 1080         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0031278762 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.84         |
# |    n_updates            | 3884         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 11           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 369          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 973          |
# |    time_elapsed         | 1081         |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0040684678 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15         |
# |    n_updates            | 3888         |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 7.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 974         |
# |    time_elapsed         | 1083        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.003901211 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68        |
# |    n_updates            | 3892        |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 8.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 365          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 975          |
# |    time_elapsed         | 1084         |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0039382027 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64         |
# |    n_updates            | 3896         |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 5.82         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 976          |
# |    time_elapsed         | 1085         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0020338595 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.43         |
# |    n_updates            | 3900         |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 6.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 360          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 977          |
# |    time_elapsed         | 1086         |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0023990208 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.11         |
# |    n_updates            | 3904         |
# |    policy_gradient_loss | 0.000503     |
# |    value_loss           | 9.61         |
# ------------------------------------------

# %%
# Save trained model
model_name = "ppo-LunarLander-v2"
model.save(model_name)

# %%
# Load trained model
model = PPO.load("ppo-LunarLander-v2")

# %%
# Evaluate and see results
eval_env = Monitor(gym.make('LunarLander-v2', render_mode="human"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=5, deterministic=True)
print(f"mean_reward={mean_reward:.2f}+/-{std_reward}")
eval_env.close()
# Out:
# mean_reward=257.92+/-23.474616856792483

# %%
package_to_hub(model = model,
               model_name="Belwen/ppo-LunarLander-v2",
               model_architecture="PPO",
               env_id="LunarLander-v2",
               eval_env=DummyVecEnv([lambda: Monitor(gym.make("LunarLander-v2", render_mode="rgb_array"))]),
               repo_id="Belwen/ppo-LunarLander-v2",
               commit_message="Upload trained ppo LunarLander")
