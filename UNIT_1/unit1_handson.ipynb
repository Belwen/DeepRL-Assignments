# %%
# Import libraires
import gymnasium as gym
from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Create environment
env = gym.make('LunarLander-v2')

# Create agent
model = PPO(policy='MlpPolicy', 
            env=env, 
            n_steps=1024,
            n_epochs=4,
            gamma=.999,
            gae_lambda=0.98,
            batch_size=32,
            ent_coef=0.01,
            verbose=1,
            learning_rate=0.0001
        )

# train agent
model.learn(total_timesteps=10000000)

# Save trained model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.7     |
# |    ep_rew_mean     | -179     |
# | time/              |          |
# |    fps             | 2566     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.1          |
# |    ep_rew_mean          | -184          |
# | time/                   |               |
# |    fps                  | 1204          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 0.00035014958 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.000869     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.74e+03      |
# |    n_updates            | 4             |
# |    policy_gradient_loss | -0.00149      |
# |    value_loss           | 6.3e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.9         |
# |    ep_rew_mean          | -195         |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 6.389158e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00138     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.000482    |
# |    value_loss           | 5.83e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.6          |
# |    ep_rew_mean          | -187          |
# | time/                   |               |
# |    fps                  | 980           |
# |    iterations           | 4             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00011563819 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.0063       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.06e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.000798     |
# |    value_loss           | 7.85e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.8          |
# |    ep_rew_mean          | -180          |
# | time/                   |               |
# |    fps                  | 953           |
# |    iterations           | 5             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00029670907 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | -0.0131       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.55e+03      |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.00155      |
# |    value_loss           | 3.32e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 94.1          |
# |    ep_rew_mean          | -167          |
# | time/                   |               |
# |    fps                  | 936           |
# |    iterations           | 6             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00010562228 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.000469     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.74e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000599     |
# |    value_loss           | 3.79e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.3          |
# |    ep_rew_mean          | -164          |
# | time/                   |               |
# |    fps                  | 925           |
# |    iterations           | 7             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.00050480105 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00936      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 799           |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.00163      |
# |    value_loss           | 1.96e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95            |
# |    ep_rew_mean          | -167          |
# | time/                   |               |
# |    fps                  | 915           |
# |    iterations           | 8             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00012663449 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00492       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.17e+03      |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.000583     |
# |    value_loss           | 2.37e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 95.9          |
# |    ep_rew_mean          | -170          |
# | time/                   |               |
# |    fps                  | 909           |
# |    iterations           | 9             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00015651813 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00116       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.5e+03       |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.000858     |
# |    value_loss           | 5.6e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.4         |
# |    ep_rew_mean          | -174         |
# | time/                   |              |
# |    fps                  | 893          |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0002288192 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0184      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.42e+03     |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 6.04e+03     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 99.2           |
# |    ep_rew_mean          | -165           |
# | time/                   |                |
# |    fps                  | 859            |
# |    iterations           | 11             |
# |    time_elapsed         | 13             |
# |    total_timesteps      | 11264          |
# | train/                  |                |
# |    approx_kl            | 0.000119092874 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.38          |
# |    explained_variance   | -0.0092        |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.44e+03       |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -0.000489      |
# |    value_loss           | 4.67e+03       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99           |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 12           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0002794423 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0488      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.78e+03     |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 3.21e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 99.8          |
# |    ep_rew_mean          | -170          |
# | time/                   |               |
# |    fps                  | 815           |
# |    iterations           | 13            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 3.4554454e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00943      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.38e+03      |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.000362     |
# |    value_loss           | 9.67e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.5         |
# |    ep_rew_mean          | -167         |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 14           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 8.375541e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.77e+03     |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.000854    |
# |    value_loss           | 5.53e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 98.1          |
# |    ep_rew_mean          | -167          |
# | time/                   |               |
# |    fps                  | 794           |
# |    iterations           | 15            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 0.00028274814 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0127       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.05e+03      |
# |    n_updates            | 56            |
# |    policy_gradient_loss | -0.00154      |
# |    value_loss           | 4.21e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.6         |
# |    ep_rew_mean          | -171         |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 16           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0003094289 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000215     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.09e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 2.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97           |
# |    ep_rew_mean          | -170         |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 17           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0002740429 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000937    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.35e+03     |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 3.07e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.6          |
# |    ep_rew_mean          | -166          |
# | time/                   |               |
# |    fps                  | 774           |
# |    iterations           | 18            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00034992344 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.034        |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.7e+03       |
# |    n_updates            | 68            |
# |    policy_gradient_loss | -0.00141      |
# |    value_loss           | 4.98e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.7          |
# |    ep_rew_mean          | -159          |
# | time/                   |               |
# |    fps                  | 769           |
# |    iterations           | 19            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00080661575 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00209      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.68e+03      |
# |    n_updates            | 72            |
# |    policy_gradient_loss | -0.00371      |
# |    value_loss           | 3.14e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.4          |
# |    ep_rew_mean          | -156          |
# | time/                   |               |
# |    fps                  | 766           |
# |    iterations           | 20            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00073265313 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00205      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.01e+03      |
# |    n_updates            | 76            |
# |    policy_gradient_loss | -0.00198      |
# |    value_loss           | 1.66e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 96.2          |
# |    ep_rew_mean          | -148          |
# | time/                   |               |
# |    fps                  | 762           |
# |    iterations           | 21            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 0.00052797794 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00104      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 356           |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00137      |
# |    value_loss           | 1.19e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94           |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 22           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0002641714 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000425     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 963          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 2.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96           |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 23           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0003337168 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000561    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 992          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 2.15e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 97.3          |
# |    ep_rew_mean          | -141          |
# | time/                   |               |
# |    fps                  | 755           |
# |    iterations           | 24            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00027396803 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.000836     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 763           |
# |    n_updates            | 92            |
# |    policy_gradient_loss | -0.000951     |
# |    value_loss           | 1.36e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.3         |
# |    ep_rew_mean          | -138         |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 25           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0008390755 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000158     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 903          |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 2.65e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -140          |
# | time/                   |               |
# |    fps                  | 751           |
# |    iterations           | 26            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00033456006 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 6.85e-06      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.14e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00124      |
# |    value_loss           | 2.84e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -136          |
# | time/                   |               |
# |    fps                  | 750           |
# |    iterations           | 27            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 0.00031662436 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00221      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 966           |
# |    n_updates            | 104           |
# |    policy_gradient_loss | -0.00174      |
# |    value_loss           | 1.35e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -137         |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 28           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0008134944 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00669     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.32e+03     |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 2.23e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -135          |
# | time/                   |               |
# |    fps                  | 748           |
# |    iterations           | 29            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00039825757 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.000469     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.2e+03       |
# |    n_updates            | 112           |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 2.85e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -137         |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 30           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0038951254 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0172       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.27e+03     |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00638     |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -134         |
# | time/                   |              |
# |    fps                  | 745          |
# |    iterations           | 31           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 8.978142e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0349       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.32e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000678    |
# |    value_loss           | 2.42e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 107           |
# |    ep_rew_mean          | -133          |
# | time/                   |               |
# |    fps                  | 743           |
# |    iterations           | 32            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00018383062 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.002        |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.1e+03       |
# |    n_updates            | 124           |
# |    policy_gradient_loss | -0.00108      |
# |    value_loss           | 2.21e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 108           |
# |    ep_rew_mean          | -131          |
# | time/                   |               |
# |    fps                  | 740           |
# |    iterations           | 33            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.00024255086 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00211      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 586           |
# |    n_updates            | 128           |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 1.34e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -131         |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 34           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 7.963902e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000932    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 542          |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000494    |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 108           |
# |    ep_rew_mean          | -129          |
# | time/                   |               |
# |    fps                  | 739           |
# |    iterations           | 35            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 35840         |
# | train/                  |               |
# |    approx_kl            | 0.00038592244 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.000376      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 824           |
# |    n_updates            | 136           |
# |    policy_gradient_loss | -0.00134      |
# |    value_loss           | 1.43e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 108           |
# |    ep_rew_mean          | -122          |
# | time/                   |               |
# |    fps                  | 738           |
# |    iterations           | 36            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00084461865 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.00412       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 894           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.0019       |
# |    value_loss           | 1.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 106           |
# |    ep_rew_mean          | -120          |
# | time/                   |               |
# |    fps                  | 738           |
# |    iterations           | 37            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 37888         |
# | train/                  |               |
# |    approx_kl            | 0.00013472547 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.000447     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 362           |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -0.000658     |
# |    value_loss           | 746           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 38           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 8.144713e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000946    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 964          |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.000698    |
# |    value_loss           | 1.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.6         |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 39           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0004014772 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00536     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 422          |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 997          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 101           |
# |    ep_rew_mean          | -114          |
# | time/                   |               |
# |    fps                  | 735           |
# |    iterations           | 40            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00018426956 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.0109       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 415           |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.000485     |
# |    value_loss           | 873           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -114          |
# | time/                   |               |
# |    fps                  | 736           |
# |    iterations           | 41            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 41984         |
# | train/                  |               |
# |    approx_kl            | 0.00034997298 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.00165      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 392           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000882     |
# |    value_loss           | 964           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -112          |
# | time/                   |               |
# |    fps                  | 735           |
# |    iterations           | 42            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00041080464 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.00224       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 484           |
# |    n_updates            | 164           |
# |    policy_gradient_loss | -0.00147      |
# |    value_loss           | 1.08e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -114          |
# | time/                   |               |
# |    fps                  | 734           |
# |    iterations           | 43            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 0.00028939568 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -0.000868     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 282           |
# |    n_updates            | 168           |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 728           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 106           |
# |    ep_rew_mean          | -116          |
# | time/                   |               |
# |    fps                  | 734           |
# |    iterations           | 44            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 3.5122794e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.0199       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 709           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | -0.000181     |
# |    value_loss           | 1.74e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 106           |
# |    ep_rew_mean          | -120          |
# | time/                   |               |
# |    fps                  | 731           |
# |    iterations           | 45            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 46080         |
# | train/                  |               |
# |    approx_kl            | 0.00082608225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.0179       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 965           |
# |    n_updates            | 176           |
# |    policy_gradient_loss | -0.00254      |
# |    value_loss           | 1.96e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 104           |
# |    ep_rew_mean          | -120          |
# | time/                   |               |
# |    fps                  | 730           |
# |    iterations           | 46            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00014978385 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -0.00199      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.91e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000746     |
# |    value_loss           | 2.6e+03       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 102           |
# |    ep_rew_mean          | -114          |
# | time/                   |               |
# |    fps                  | 728           |
# |    iterations           | 47            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 48128         |
# | train/                  |               |
# |    approx_kl            | 0.00048713968 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | -1.68e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 333           |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -0.00163      |
# |    value_loss           | 736           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 48           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0014871855 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000529    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 345          |
# |    n_updates            | 188          |
# |    policy_gradient_loss | 0.000933     |
# |    value_loss           | 548          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 103           |
# |    ep_rew_mean          | -111          |
# | time/                   |               |
# |    fps                  | 727           |
# |    iterations           | 49            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 50176         |
# | train/                  |               |
# |    approx_kl            | 0.00038026227 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -9.36e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 640           |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.00191      |
# |    value_loss           | 1.29e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -109         |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 50           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0001317779 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00747     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 557          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000385    |
# |    value_loss           | 1.09e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 102           |
# |    ep_rew_mean          | -106          |
# | time/                   |               |
# |    fps                  | 727           |
# |    iterations           | 51            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 52224         |
# | train/                  |               |
# |    approx_kl            | 0.00023491465 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.00126       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 350           |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00136      |
# |    value_loss           | 1.46e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 110           |
# |    ep_rew_mean          | -105          |
# | time/                   |               |
# |    fps                  | 727           |
# |    iterations           | 52            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00048457575 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.00926       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 304           |
# |    n_updates            | 204           |
# |    policy_gradient_loss | -0.002        |
# |    value_loss           | 794           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 110           |
# |    ep_rew_mean          | -106          |
# | time/                   |               |
# |    fps                  | 727           |
# |    iterations           | 53            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 54272         |
# | train/                  |               |
# |    approx_kl            | 0.00040467677 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.114         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 54.3          |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0065828916 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 11.5         |
# |    n_updates            | 2104         |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 25.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 790         |
# |    ep_rew_mean          | 74.9        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 528         |
# |    time_elapsed         | 143972      |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.006618428 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.21        |
# |    n_updates            | 2108        |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 9.23        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 790        |
# |    ep_rew_mean          | 74.6       |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 529        |
# |    time_elapsed         | 143973     |
# |    total_timesteps      | 541696     |
# | train/                  |            |
# |    approx_kl            | 0.00945648 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.72       |
# |    n_updates            | 2112       |
# |    policy_gradient_loss | -0.00559   |
# |    value_loss           | 6.52       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 790         |
# |    ep_rew_mean          | 74.9        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 530         |
# |    time_elapsed         | 143975      |
# |    total_timesteps      | 542720      |
# | train/                  |             |
# |    approx_kl            | 0.007994628 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.32        |
# |    n_updates            | 2116        |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 14.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | 75.4         |
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 531          |
# |    time_elapsed         | 143976       |
# |    total_timesteps      | 543744       |
# | train/                  |              |
# |    approx_kl            | 0.0001321907 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.709        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 516          |
# |    n_updates            | 2120         |
# |    policy_gradient_loss | -7.13e-05    |
# |    value_loss           | 362          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 797          |
# |    ep_rew_mean          | 76.7         |
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 532          |
# |    time_elapsed         | 143977       |
# |    total_timesteps      | 544768       |
# | train/                  |              |
# |    approx_kl            | 0.0049842987 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.7          |
# |    n_updates            | 2124         |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 19.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 797         |
# |    ep_rew_mean          | 76.4        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 533         |
# |    time_elapsed         | 143979      |
# |    total_timesteps      | 545792      |
# | train/                  |             |
# |    approx_kl            | 0.006760941 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.02        |
# |    n_updates            | 2128        |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 7.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 797         |
# |    ep_rew_mean          | 76.2        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 534         |
# |    time_elapsed         | 143980      |
# |    total_timesteps      | 546816      |
# | train/                  |             |
# |    approx_kl            | 0.010396207 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.07        |
# |    n_updates            | 2132        |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 798         |
# |    ep_rew_mean          | 76.5        |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 535         |
# |    time_elapsed         | 143981      |
# |    total_timesteps      | 547840      |
# | train/                  |             |
# |    approx_kl            | 0.009341847 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.06        |
# |    n_updates            | 2136        |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 5.96        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 78.1         |
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 536          |
# |    time_elapsed         | 143983       |
# |    total_timesteps      | 548864       |
# | train/                  |              |
# |    approx_kl            | 0.0054586423 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.4          |
# |    n_updates            | 2140         |
# |    policy_gradient_loss | 0.000342     |
# |    value_loss           | 7.48         |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#       5 model = PPO(policy='MlpPolicy',
#       6             env=env,
#       7             n_steps=1024,
#    (...)
#      14             learning_rate=0.0001
#      15         )
#      17 # train agent
# ---> 18 model.learn(total_timesteps=10000000)
#      20 # Save trained model
#      21 model_name = "ppo-LunarLander-v2"
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:179, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     176 with th.no_grad():
#     177     # Convert to pytorch tensor or to TensorDict
#     178     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 179     actions, values, log_probs = self.policy(obs_tensor)
#     180 actions = actions.cpu().numpy()
#     182 # Rescale and perform action
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\common\policies.py:647, in ActorCriticPolicy.forward(self, obs, deterministic)
#     645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
# --> 647     latent_pi, latent_vf = self.mlp_extractor(features)
#     648 else:
#     649     pi_features, vf_features = features
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\common\torch_layers.py:222, in MlpExtractor.forward(self, features)
#     217 def forward(self, features: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
#     218     """
#     219     :return: latent_policy, latent_value of the specified network.
#     220         If all layers are shared, then ``latent_policy == latent_value``
#     221     """
# --> 222     return self.forward_actor(features), self.forward_critic(features)
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\stable_baselines3\common\torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Sarah\anaconda3\envs\deeprl_env\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Save trained model
model_name = "ppo-LunarLander-v2"
model.save(model_name)

# %%
# Load trained model
model = PPO.load("ppo-LunarLander-v2")

# %%
# Evaluate and see results
eval_env = Monitor(gym.make('LunarLander-v2', render_mode="human"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=5, deterministic=True)
print(f"mean_reward={mean_reward:.2f}+/-{std_reward}")
eval_env.close()
# Out:
# mean_reward=236.31+/-93.6811385555405

# %%
package_to_hub(model = model,
               model_name="Belwen/ppo-LunarLander-v2",
               model_architecture="PPO",
               env_id="LunarLander-v2",
               eval_env=DummyVecEnv([lambda: Monitor(gym.make("LunarLander-v2", render_mode="rgb_array"))]),
               repo_id="Belwen/ppo-LunarLander-v2",
               commit_message="Upload trained ppo LunarLander")
